# %% [markdown]
# # Aufgabe 1:
# Spielen Sie das toxicode-Spiel: https://compute-it.toxicode.fr/

# %% [markdown]
# # Text eingeben
# hier einen beliebigen Text eingeben und mit STRG+EING anzeigen lassen

# %%
# Python Code eingeben und ausführen (auch mit STRG+EING)
print (2+2)
print (7*8)
print ("Text")
# Out:
# 4
# 56
# Text

# %% [markdown]
# # Grafiken einfügen
# Am einfachsten speichert man ein Bild oder ein Screenshot zwischen und fügt man es mit ```STRG+V``` in eine __Textzelle (Markdown-Zelle)__ ein.

# %% [markdown]
# ![image.png](attachment:b0b8ebb9-b116-472f-9d0c-618f1b8adaeb.png)

# %% [markdown]
# # Aufgabe 2:
# Fügen Sie hier eine beliebige Grafik als Screenshot ein.

# %% [markdown]
# # Struktogramme erzeugen
#
# Eine toxicode-Aufgabe kann man als Struktogramm (Nassi–Shneiderman-Diagramm) darstellen:
# ### toxicode-Aufgabe 1
# ![image.png](attachment:0ff62896-4199-43d7-a4cf-c9a966dcd1cf.png)
# ### Struktogramm 1
# ![image.png](attachment:b1276127-4cb5-4b38-8a14-77383a320902.png)
#
# Öffnen Sie die Datei _Struktogrammer.ipynb_ im Ordner _Struktogrammer_(siehe links).
# Zeichnen Sie die Struktogramme zu den folgenden toxicode-Aufgaben, machen Sie ein Screenshot davon und fügen Sie es hier ein.
# ### toxicode-Aufgabe 2
# ![image.png](attachment:e64fdcf3-4a9b-4319-a4be-e4c8b6e1e991.png)

# %% [markdown]
# ### Struktogramm 2

# %% [markdown]
# ### toxicode-Aufgabe 3
# ![image.png](attachment:61079971-0344-4356-a466-c09c69c71b3f.png)

# %% [markdown]
# ### Struktogramm 3

# %% [markdown]
# ### toxicode-Aufgabe 4
# ![image.png](attachment:8da8eb65-e253-4c47-844e-0db3a1f6426d.png)

# %% [markdown]
# ### Struktogramm 4

# %% [markdown]
# # Diese Dateien als PDF speichern
# Mit STRG+P zum Drucken-Fenster wechseln und in die PDF-Datei "drucken" lassen.
