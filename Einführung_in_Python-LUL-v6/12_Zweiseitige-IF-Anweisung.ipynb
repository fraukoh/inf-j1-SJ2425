# %% [markdown]
# # Die zweiseitige if-Anweisung / Verzweigung
# Bei der einseitigen if-Anweisung wird nur der True-Zweig berücksichtigt. Es werden dann nur Anweisungen ausgeführt, wenn die Bedingung wahr ist. Im folgenden Beispiel gibt es auch eine Anweisung, wenn die Bedingung falsch ist.

# %%
alter = int(input("Bitte geben Sie Ihr Alter in Jahren an: "))
if alter > 17:
    print("Sie sind erwachsen!")
else:
    print("Sie sind minderjährig!")
print("Programmende!")
# Out:
# Bitte geben Sie Ihr Alter in Jahren an:  15
# Sie sind minderjährig!
# Programmende!

# %% [markdown]
# Die if-Anweisung wird mit else erweitert. Nach dem True-Block wird der False-Block mit dem Schlüsselwort else eingeleitet. Beachten Sie auch hier den Doppelpunkt nach dem Schlüsselwort else sowie die darauf folgende Einrückung der Anweisungen, die zum else-Block gehören.
# Testen Sie das Programm und variieren Sie es, bis Sie den Aufbau der Blöcke gut vor Augen haben.

# %% [markdown]
# # Struktogramm:

# %% [markdown]
# ![image.png](attachment:cb940b5e-b0c4-4de9-b5ec-f9eab4b17ab6.png)
