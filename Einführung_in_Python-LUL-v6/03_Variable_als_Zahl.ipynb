# %% [markdown]
# # Variable als Zahl
# Möchte man Berechnungen durchführen, benötigt man Zahlen, die wiederum in Variablen gespeichert werden können. Es können sowohl Ganzzahlen als auch Dezimalzahlen verwendet werden.

# %%
# Beispiel:
erste_zahl = 3
zweite_zahl = 3.14
print(erste_zahl, zweite_zahl)

# %% [markdown]
# ## Struktogramm:

# %% [markdown]
# ![image.png](attachment:eb8f75c9-e41d-4b77-ae98-e9878f226851.png)
