# %% [markdown]
# # Aufgabe - Wiederholung mit while-Schleife:
# ### Problemstellung
# Auf einem Sparbuch wird ein Geldbetrag angelegt. Für diesen Betrag gibt es einen bestimmten Zinssatz. In diesem Projekt soll überprüft werden, wie viele Jahre es dauert, bis dieser Betrag einen bestimmten Zielwert erreicht ober überschreitet. Dabei sollen die Jahresendwerte der Finanzanlage jeweils ausgegeben werden. (Zinseszinsen nicht vergessen!)
# ### Problemanalyse:
# #### Welche Ausgabedaten will man erhalten?

# %% [markdown]
# Die Jahresendwerte des Betrages der Finanzanlage, solange bis der gewünschte Zielwert erreicht oder überschritten wurde.

# %% [markdown]
# #### Welche Daten werden zur Bearbeitung benötigt?

# %% [markdown]
# Ausgangsbetrag in Euro
# Zinssatz in Prozent
# Zielwert in Euro

# %% [markdown]
# #### Welche Eigenschaften haben die Ausgabedaten? (Variablenliste)

# %% [markdown]
# |Bedeutung|Datentyp|Variable|
# |--|--|--|
# |Eingabe: Zielwert der Anlage|Dezimalzahl|zielwert|
# |Eingabe und Verarbeitung: Zinssatz|Dezimalzahl|zinssatz|
# |Verarbeitung: aktuelles Jahr der Anlage|Ganzzahl|jahr|
# |Eingabe, Verarbeitung und Ausgabe: 	aktueller Betrag der Anlage|Dezimalzahl|anlagebetrag|

# %% [markdown]
# #### So soll die Bildschirmausgabe des Programms aussehen (Beispiel):
# ```
# Welcher Betrag soll angelegt werden? 1000
# Zu welchem prozentualen Zinssatz wird verzinst? 2
# Welcher Zielwert soll erreicht werden? 1200
# Jahr 1 : 1020.0
# Jahr 2 : 1040.4
# Jahr 3 : 1061.208
# Jahr 4 : 1082.43216
# ...
# ```

# %% [markdown]
# ### Struktogramm:
# Zeichnen Sie ein Struktogramm zu diesem Programm.

# %% [markdown]
# ![image.png](attachment:d5fe2293-6848-4755-a46d-5721d2986012.png)

# %% [markdown]
# ### Programmcode (Python-Code)

# %%
#Hier den Programmcode eingeben und mit STRG+ENTER ausführen
anlagebetrag = float(input("Welcher Betrag soll angelegt werden? "))
zinssatz = float(input("Zu welchem prozentualen Zinssatz wird verzinst? "))
zielwert = float(input("Welcher Zielwert soll erreicht werden? "))
jahr = 0
while anlagebetrag < zielwert:
    anlagebetrag = anlagebetrag * (1 + (zinssatz / 100))
    jahr = jahr + 1
    print("Jahr", jahr, ":", anlagebetrag)
# Out:
# Welcher Betrag soll angelegt werden?  1000
# Zu welchem prozentualen Zinssatz wird verzinst?  2
# Welcher Zielwert soll erreicht werden?  1200
# Jahr 1 : 1020.0
# Jahr 2 : 1040.4
# Jahr 3 : 1061.208
# Jahr 4 : 1082.43216
# Jahr 5 : 1104.0808032
# Jahr 6 : 1126.162419264
# Jahr 7 : 1148.68566764928
# Jahr 8 : 1171.6593810022657
# Jahr 9 : 1195.092568622311
# Jahr 10 : 1218.9944199947574
