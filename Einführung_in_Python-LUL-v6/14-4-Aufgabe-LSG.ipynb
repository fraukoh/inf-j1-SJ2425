# %% [markdown]
# # Aufgabe: Verzweigung mit verknüpften Bedingungen (AND) – Anmeldung BG
# ### Problemstellung
# In diesem Projekt soll der gleiche Sachverhalt wie in _142-Aufgabe.ipynb_ umgesetzt werden. Hier sollen jedoch logische Operatoren anstelle einer Verschachtelung der Verzweigungen verwendet werden.
# ### Problemanalyse:
# #### Welche Ausgabedaten will man erhalten?

# %% [markdown]
# Antwortsatz „Die Anmeldung ist möglich/nicht möglich“

# %% [markdown]
# #### Welche Daten werden zur Bearbeitung benötigt?

# %% [markdown]
# Die Noten in den Fächern Deutsch, Mathematik und Englisch

# %% [markdown]
# #### Welche Eigenschaften haben die Ausgabedaten? (Variablenliste)

# %% [markdown]
# |Bedeutung|Datentyp|Variable|
# |--|--|--|
# |Eingabe: Note Fach Deutsch|Ganzzahl|note_deutsch|
# |Eingabe: Note Fach Mathematik|Ganzzahl|note_mathematik|
# |Eingabe: Note Fach Englisch|Ganzzahl|note_englisch|
# |Verarbeitung: Zulassung zur Aufnahme|Wahrheitswert|ist_zugelassen|
# |Ausgabe: Antwortsatz|Zeichenkette|ohne Variable|

# %% [markdown]
# #### So soll die Bildschirmausgabe des Programms aussehen (Beispiel):
# ```
# Deutschnote: 3
# Englischnote: 3
# Mathematiknote: 3
# Die Aufnahme ist möglich.
# ```

# %% [markdown]
# ### Struktogramm:
# Zeichnen Sie ein Struktogramm zu diesem Programm.

# %% [markdown]
# ![image.png](attachment:eee7326d-a964-44a1-88be-c355a6afa46e.png)

# %% [markdown]
# ### Programmcode (Python-Code)

# %%
#Hier den Programmcode eingeben und mit STRG+ENTER ausführen
note_deutsch = int(input("Deutschnote: "))
note_englisch = int(input("Englischnote: "))
note_mathematik = int(input("Mathematiknote: "))
ist_zugelassen = False
if note_deutsch <= 4 and note_englisch <= 4 and note_mathematik <= 4 and (
    note_deutsch + note_englisch + note_mathematik) / 3 <= 3:
                ist_zugelassen = True
if ist_zugelassen:
    print("Die Aufnahme ist möglich.")
else:
    print("Aufnahme ist nicht möglich.")
# Out:
# Deutschnote:  3
# Englischnote:  3
# Mathematiknote:  3
# Die Aufnahme ist möglich.
